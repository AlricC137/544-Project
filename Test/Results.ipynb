# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd "/content/drive/MyDrive/544 Project/"
# Out:
# Mounted at /content/drive
# /content/drive/.shortcut-targets-by-id/1X1HQ_JbFBub59HaYyHz4gNN-B89ZOL7e/544 Project

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_excel("./Test/results.xlsx")
df1
# Out:
#              task                     model model_source  \
# 0              qa  Qwen/Qwen2.5-3B-Instruct         base
# 1              qa  Qwen/Qwen2.5-3B-Instruct         lora
# 2              qa  Qwen/Qwen2.5-3B-Instruct      sc-lora
# 3              qa      google/gemma-3-4b-it         base
# 4              qa      google/gemma-3-4b-it         lora
# 5              qa      google/gemma-3-4b-it      sc-lora
# 6        dialogue  Qwen/Qwen2.5-3B-Instruct         base
# 7        dialogue  Qwen/Qwen2.5-3B-Instruct         lora
# 8        dialogue      google/gemma-3-4b-it      sc-lora
# 9        dialogue      google/gemma-3-4b-it         base
# 10       dialogue      google/gemma-3-4b-it         lora
# 11       dialogue  Qwen/Qwen2.5-3B-Instruct      sc-lora
# 12  summarization  Qwen/Qwen2.5-3B-Instruct         base
# 13  summarization  Qwen/Qwen2.5-3B-Instruct         lora
# 14  summarization      google/gemma-3-4b-it         base
# ...

# %%
df1.columns
# Out:
# Index(['task', 'model', 'model_source', 'lora_path', 'total', 'valid',
#        'failed', 'correct', 'incorrect', 'accuracy_all', 'accuracy_valid',
#        'precision_yes', 'recall_yes', 'f1_yes', 'sc_n_samples'],
#       dtype='object')

# %%
df1 = df1[["task", "model", "model_source", "accuracy_all", "f1_yes"]]
df1
# Out:
#              task                     model model_source  accuracy_all  f1_yes
# 0              qa  Qwen/Qwen2.5-3B-Instruct         base        0.4962  0.0217
# 1              qa  Qwen/Qwen2.5-3B-Instruct         lora        0.5022  0.0812
# 2              qa  Qwen/Qwen2.5-3B-Instruct      sc-lora        0.5026  0.1483
# 3              qa      google/gemma-3-4b-it         base        0.5012  0.6367
# 4              qa      google/gemma-3-4b-it         lora        0.5012  0.0739
# 5              qa      google/gemma-3-4b-it      sc-lora        0.4943  0.3152
# 6        dialogue  Qwen/Qwen2.5-3B-Instruct         base        0.5869  0.4234
# 7        dialogue  Qwen/Qwen2.5-3B-Instruct         lora        0.5870  0.3510
# 8        dialogue      google/gemma-3-4b-it      sc-lora        0.5333  0.3662
# 9        dialogue      google/gemma-3-4b-it         base        0.6125  0.6597
# 10       dialogue      google/gemma-3-4b-it         lora        0.5204  0.0968
# ...

# %%
df2 = pd.read_excel("./Test/gc_results.xlsx")
df2
# Out:
#             task generator checker            gen_base_model  \
# 0             qa     gemma    qwen      google/gemma-3-4b-it
# 1             qa      qwen   gemma  Qwen/Qwen2.5-3B-Instruct
# 2       dialogue     gemma    qwen      google/gemma-3-4b-it
# 3       dialogue      qwen   gemma  Qwen/Qwen2.5-3B-Instruct
# 4  summarization     gemma    qwen      google/gemma-3-4b-it
# 5  summarization      qwen   gemma  Qwen/Qwen2.5-3B-Instruct
#
#              chk_base_model model_source  max_rounds  total  valid  failed  \
# 0  Qwen/Qwen2.5-3B-Instruct      gc-lora           1   2000   2000       0
# 1      google/gemma-3-4b-it      gc-lora           1   2000   2000       0
# 2  Qwen/Qwen2.5-3B-Instruct      gc-lora           1   2000   2000       0
# 3      google/gemma-3-4b-it      gc-lora           1   2000   2000       0
# 4  Qwen/Qwen2.5-3B-Instruct      gc-lora           1   2000   1600     400
# 5      google/gemma-3-4b-it      gc-lora           1   2000   1789     211
#
# ...

# %%
df2.columns
# Out:
# Index(['task', 'generator', 'checker', 'gen_base_model', 'chk_base_model',
#        'model_source', 'max_rounds', 'total', 'valid', 'failed', 'correct',
#        'incorrect', 'avg_rounds', 'accuracy_all', 'accuracy_valid',
#        'precision_yes', 'recall_yes', 'f1_yes', 'detected', 'corrected',
#        'detection_rate', 'correction_rate'],
#       dtype='object')

# %%
df2 = df2[["task", "generator", "checker", "detection_rate", "correction_rate"]]
df2
# Out:
#             task generator checker  detection_rate  correction_rate
# 0             qa     gemma    qwen          0.7759           0.3150
# 1             qa      qwen   gemma          0.0000           0.0000
# 2       dialogue     gemma    qwen          0.1950           0.9104
# 3       dialogue      qwen   gemma          0.0078           0.1250
# 4  summarization     gemma    qwen          0.5112           0.7400
# 5  summarization      qwen   gemma          0.0019           0.0000
